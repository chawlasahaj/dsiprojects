# %% [markdown]
# # Ames Housing Data
# The main purpose of this data science project is to predict the home prices in Ames, Iowa by using regression models. By doing this data analysis, we can find the theoretical relationship have in mind. Probably, there is specific interest in the magnitudes and signs of the coefficients. Throughout the iterative modeling and feature selection processes manually and automatedly, we can gain a deeper insight into 80 variables which were directly related to property sales and understand better the mechanism behind various models.
#
#
#
# ## Problem Statement - What features most affect home sales prices in Ames, IA? What modeling approaches yield the most accurate predictions of Sales Price?

# %% [markdown]
# # Imports and Loading Data

# %%
# Libraries to use for EDA
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Libraries to use for Linear Regression Modeling
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.linear_model import LinearRegression, LassoCV, RidgeCV
from sklearn.preprocessing import StandardScaler, PolynomialFeatures, PowerTransformer
from sklearn.metrics import r2_score

# %matplotlib inline

# %%
pd.options.display.max_columns = 400
pd.options.display.max_rows = 300

# %%
# Import data
train = pd.read_csv('./datasets/train.csv')

test = pd.read_csv('./datasets/test.csv')

# %%
train.columns
# Out:
# Index(['Id', 'PID', 'MS SubClass', 'MS Zoning', 'Lot Frontage', 'Lot Area',
#        'Street', 'Alley', 'Lot Shape', 'Land Contour', 'Utilities',
#        'Lot Config', 'Land Slope', 'Neighborhood', 'Condition 1',
#        'Condition 2', 'Bldg Type', 'House Style', 'Overall Qual',
#        'Overall Cond', 'Year Built', 'Year Remod/Add', 'Roof Style',
#        'Roof Matl', 'Exterior 1st', 'Exterior 2nd', 'Mas Vnr Type',
#        'Mas Vnr Area', 'Exter Qual', 'Exter Cond', 'Foundation', 'Bsmt Qual',
#        'Bsmt Cond', 'Bsmt Exposure', 'BsmtFin Type 1', 'BsmtFin SF 1',
#        'BsmtFin Type 2', 'BsmtFin SF 2', 'Bsmt Unf SF', 'Total Bsmt SF',
#        'Heating', 'Heating QC', 'Central Air', 'Electrical', '1st Flr SF',
#        '2nd Flr SF', 'Low Qual Fin SF', 'Gr Liv Area', 'Bsmt Full Bath',
#        'Bsmt Half Bath', 'Full Bath', 'Half Bath', 'Bedroom AbvGr',
#        'Kitchen AbvGr', 'Kitchen Qual', 'TotRms AbvGrd', 'Functional',
# ...

# %%
train.shape
# Out:
# (2051, 81)

# %%
train.info
# Out:
# <bound method DataFrame.info of         Id        PID  MS SubClass MS Zoning  Lot Frontage  Lot Area Street  \
# 0      109  533352170           60        RL           NaN     13517   Pave
# 1      544  531379050           60        RL          43.0     11492   Pave
# 2      153  535304180           20        RL          68.0      7922   Pave
# 3      318  916386060           60        RL          73.0      9802   Pave
# 4      255  906425045           50        RL          82.0     14235   Pave
# ...    ...        ...          ...       ...           ...       ...    ...
# 2046  1587  921126030           20        RL          79.0     11449   Pave
# 2047   785  905377130           30        RL           NaN     12342   Pave
# 2048   916  909253010           50        RL          57.0      7558   Pave
# 2049   639  535179160           20        RL          80.0     10400   Pave
# 2050    10  527162130           60        RL          60.0      7500   Pave
#
# ...

# %%
train.describe().T
# Out:
#                   count          mean           std          min          25%  \
# Id               2051.0  1.474034e+03  8.439808e+02          1.0        753.5
# PID              2051.0  7.135900e+08  1.886918e+08  526301100.0  528458140.0
# MS SubClass      2051.0  5.700878e+01  4.282422e+01         20.0         20.0
# Lot Frontage     1721.0  6.905520e+01  2.326065e+01         21.0         58.0
# Lot Area         2051.0  1.006521e+04  6.742489e+03       1300.0       7500.0
# Overall Qual     2051.0  6.112140e+00  1.426271e+00          1.0          5.0
# Overall Cond     2051.0  5.562165e+00  1.104497e+00          1.0          5.0
# Year Built       2051.0  1.971709e+03  3.017789e+01       1872.0       1953.5
# Year Remod/Add   2051.0  1.984190e+03  2.103625e+01       1950.0       1964.5
# Mas Vnr Area     2029.0  9.969591e+01  1.749631e+02          0.0          0.0
# BsmtFin SF 1     2050.0  4.423005e+02  4.612041e+02          0.0          0.0
# ...

# %%
train.head()
# Out:
#     Id        PID  MS SubClass MS Zoning  Lot Frontage  Lot Area Street Alley  \
# 0  109  533352170           60        RL           NaN     13517   Pave   NaN
# 1  544  531379050           60        RL          43.0     11492   Pave   NaN
# 2  153  535304180           20        RL          68.0      7922   Pave   NaN
# 3  318  916386060           60        RL          73.0      9802   Pave   NaN
# 4  255  906425045           50        RL          82.0     14235   Pave   NaN
#
#   Lot Shape Land Contour Utilities Lot Config Land Slope Neighborhood  \
# 0       IR1          Lvl    AllPub    CulDSac        Gtl       Sawyer
# 1       IR1          Lvl    AllPub    CulDSac        Gtl      SawyerW
# 2       Reg          Lvl    AllPub     Inside        Gtl        NAmes
# 3       Reg          Lvl    AllPub     Inside        Gtl       Timber
# 4       IR1          Lvl    AllPub     Inside        Gtl      SawyerW
#
# ...

# %%
train.dtypes
# Out:
# Id                   int64
# PID                  int64
# MS SubClass          int64
# MS Zoning           object
# Lot Frontage       float64
# Lot Area             int64
# Street              object
# Alley               object
# Lot Shape           object
# Land Contour        object
# Utilities           object
# Lot Config          object
# Land Slope          object
# Neighborhood        object
# Condition 1         object
# Condition 2         object
# Bldg Type           object
# House Style         object
# Overall Qual         int64
# Overall Cond         int64
# Year Built           int64
# Year Remod/Add       int64
# Roof Style          object
# Roof Matl           object
# Exterior 1st        object
# Exterior 2nd        object
# Mas Vnr Type        object
# Mas Vnr Area       float64
# Exter Qual          object
# Exter Cond          object
# Foundation          object
# Bsmt Qual           object
# Bsmt Cond           object
# Bsmt Exposure       object
# ...

# %%
test.shape
# Out:
# (879, 80)

# %%
test.info
# Out:
# <bound method DataFrame.info of        Id        PID  MS SubClass MS Zoning  Lot Frontage  Lot Area Street  \
# 0    2658  902301120          190        RM          69.0      9142   Pave
# 1    2718  905108090           90        RL           NaN      9662   Pave
# 2    2414  528218130           60        RL          58.0     17104   Pave
# 3    1989  902207150           30        RM          60.0      8520   Pave
# 4     625  535105100           20        RL           NaN      9500   Pave
# ..    ...        ...          ...       ...           ...       ...    ...
# 874  1662  527377110           60        RL          80.0      8000   Pave
# 875  1234  535126140           60        RL          90.0     14670   Pave
# 876  1373  904100040           20        RL          55.0      8250   Pave
# 877  1672  527425140           20        RL          60.0      9000   Pave
# 878  1939  535327160           20        RL          70.0      8400   Pave
#
# ...

# %%
test.describe().T
# Out:
#                  count          mean           std          min          25%  \
# Id               879.0  1.445588e+03  8.507171e+02          2.0        692.5
# PID              879.0  7.165050e+08  1.889135e+08  526302110.0  528486085.0
# MS SubClass      879.0  5.827076e+01  4.221139e+01         20.0         20.0
# Lot Frontage     719.0  6.963004e+01  2.362537e+01         21.0         59.0
# Lot Area         879.0  1.034092e+04  1.004734e+04       1477.0       7298.5
# Overall Qual     879.0  6.054608e+00  1.374756e+00          2.0          5.0
# Overall Cond     879.0  5.565415e+00  1.128422e+00          1.0          5.0
# Year Built       879.0  1.970534e+03  3.040353e+01       1880.0       1954.0
# Year Remod/Add   879.0  1.984445e+03  2.045455e+01       1950.0       1967.0
# Mas Vnr Area     878.0  1.069829e+02  1.883568e+02          0.0          0.0
# BsmtFin SF 1     879.0  4.433970e+02  4.424802e+02          0.0          0.0
# ...

# %%
test.head()
# Out:
#      Id        PID  MS SubClass MS Zoning  Lot Frontage  Lot Area Street  \
# 0  2658  902301120          190        RM          69.0      9142   Pave
# 1  2718  905108090           90        RL           NaN      9662   Pave
# 2  2414  528218130           60        RL          58.0     17104   Pave
# 3  1989  902207150           30        RM          60.0      8520   Pave
# 4   625  535105100           20        RL           NaN      9500   Pave
#
#   Alley Lot Shape Land Contour Utilities Lot Config Land Slope Neighborhood  \
# 0  Grvl       Reg          Lvl    AllPub     Inside        Gtl      OldTown
# 1   NaN       IR1          Lvl    AllPub     Inside        Gtl       Sawyer
# 2   NaN       IR1          Lvl    AllPub     Inside        Gtl      Gilbert
# 3   NaN       Reg          Lvl    AllPub     Inside        Gtl      OldTown
# 4   NaN       IR1          Lvl    AllPub     Inside        Gtl        NAmes
#
# ...

# %%
test.dtypes
# Out:
# Id                   int64
# PID                  int64
# MS SubClass          int64
# MS Zoning           object
# Lot Frontage       float64
# Lot Area             int64
# Street              object
# Alley               object
# Lot Shape           object
# Land Contour        object
# Utilities           object
# Lot Config          object
# Land Slope          object
# Neighborhood        object
# Condition 1         object
# Condition 2         object
# Bldg Type           object
# House Style         object
# Overall Qual         int64
# Overall Cond         int64
# Year Built           int64
# Year Remod/Add       int64
# Roof Style          object
# Roof Matl           object
# Exterior 1st        object
# Exterior 2nd        object
# Mas Vnr Type        object
# Mas Vnr Area       float64
# Exter Qual          object
# Exter Cond          object
# Foundation          object
# Bsmt Qual           object
# Bsmt Cond           object
# Bsmt Exposure       object
# ...

# %% [markdown]
# # Data Cleaning and EDA

# %%
#column names formatting
train.columns = [i.lower().replace(' ','_') for i in train.columns]

# %%
#column names formatting
test.columns = [i.lower().replace(' ','_') for i in test.columns]

# %%
train.isnull().sum()[train.isnull().sum()>0]
# Out:
# lot_frontage       330
# alley             1911
# mas_vnr_type        22
# mas_vnr_area        22
# bsmt_qual           55
# bsmt_cond           55
# bsmt_exposure       58
# bsmtfin_type_1      55
# bsmtfin_sf_1         1
# bsmtfin_type_2      56
# bsmtfin_sf_2         1
# bsmt_unf_sf          1
# total_bsmt_sf        1
# bsmt_full_bath       2
# bsmt_half_bath       2
# fireplace_qu      1000
# garage_type        113
# garage_yr_blt      114
# garage_finish      114
# garage_cars          1
# garage_area          1
# garage_qual        114
# garage_cond        114
# pool_qc           2042
# fence             1651
# misc_feature      1986
# dtype: int64

# %%
test.isnull().sum()[test.isnull().sum()>0]
# Out:
# lot_frontage      160
# alley             821
# mas_vnr_type        1
# mas_vnr_area        1
# bsmt_qual          25
# bsmt_cond          25
# bsmt_exposure      25
# bsmtfin_type_1     25
# bsmtfin_type_2     25
# electrical          1
# fireplace_qu      422
# garage_type        44
# garage_yr_blt      45
# garage_finish      45
# garage_qual        45
# garage_cond        45
# pool_qc           875
# fence             707
# misc_feature      838
# dtype: int64

# %%
train[train['lot_frontage'].isnull()].head()
# Out:
#       id        pid  ms_subclass ms_zoning  lot_frontage  lot_area street  \
# 0    109  533352170           60        RL           NaN     13517   Pave
# 7    145  535154050           20        RL           NaN     12160   Pave
# 8   1942  535353130           20        RL           NaN     15783   Pave
# 23    12  527165230           20        RL           NaN      7980   Pave
# 27  1534  909277040           50        RL           NaN     11700   Pave
#
#    alley lot_shape land_contour utilities lot_config land_slope neighborhood  \
# 0    NaN       IR1          Lvl    AllPub    CulDSac        Gtl       Sawyer
# 7    NaN       IR1          Lvl    AllPub     Inside        Gtl        NAmes
# 8    NaN       Reg          Lvl    AllPub     Inside        Gtl      OldTown
# 23   NaN       IR1          Lvl    AllPub     Inside        Gtl      Gilbert
# 27  Grvl       IR1          HLS    AllPub     Inside        Mod      Crawfor
#
# ...

# %%
train[(train['lot_frontage'].isnull())&(train['lot_config'].str.contains('FR'))].head()
# Out:
#        id        pid  ms_subclass ms_zoning  lot_frontage  lot_area street  \
# 106  2513  533223080          160        FV           NaN      2651   Pave
# 226   973  923203190          120        RM           NaN      4500   Pave
# 335   493  528292070           60        RL           NaN      8755   Pave
# 430  1848  533223050          160        FV           NaN      5105   Pave
# 454   104  533223100          160        FV           NaN      2403   Pave
#
#     alley lot_shape land_contour utilities lot_config land_slope neighborhood  \
# 106   NaN       Reg          Lvl    AllPub        FR2        Gtl      Somerst
# 226   NaN       Reg          Lvl    AllPub        FR2        Gtl      Mitchel
# 335   NaN       IR1          Lvl    AllPub        FR2        Gtl      Gilbert
# 430   NaN       IR2          Lvl    AllPub        FR2        Gtl      Somerst
# 454   NaN       IR1          Lvl    AllPub        FR2        Gtl      Somerst
#
# ...

# %%
train[(train['lot_frontage'].isnull())&(train['lot_config'].str.contains('FR'))].shape[0]
# Out:
# 12

# %%
train.drop(train[(train['lot_frontage'].isnull())&(train['lot_config'].str.contains('FR'))].index, inplace=True)

# %%
train['lot_frontage'].fillna(0,inplace=True)

# %%
test['lot_frontage'].fillna(0,inplace=True)

# %%
train[train.mas_vnr_type.isnull()].head()
# Out:
#        id        pid  ms_subclass ms_zoning  lot_frontage  lot_area street  \
# 22   2393  528142010           60        RL         103.0     12867   Pave
# 41   2383  528110050           20        RL         107.0     13891   Pave
# 86    539  531371050           20        RL          67.0     10083   Pave
# 212   518  528458020           20        FV          90.0      7993   Pave
# 276  2824  908130020           20        RL          75.0      8050   Pave
#
#     alley lot_shape land_contour utilities lot_config land_slope neighborhood  \
# 22    NaN       IR1          Lvl    AllPub     Corner        Gtl      NridgHt
# 41    NaN       Reg          Lvl    AllPub     Inside        Gtl      NridgHt
# 86    NaN       Reg          Lvl    AllPub     Inside        Gtl      SawyerW
# 212   NaN       IR1          Lvl    AllPub     Inside        Gtl      Somerst
# 276   NaN       Reg          Lvl    AllPub     Inside        Gtl      Edwards
#
# ...

# %%
train[train.mas_vnr_type.isnull()].shape[0]
# Out:
# 22

# %%
train.mas_vnr_type.fillna('None',inplace=True)

# %%
train.mas_vnr_area.fillna(0,inplace=True)

# %%
test.mas_vnr_type.fillna('None',inplace=True)

# %%
test.mas_vnr_area.fillna(0,inplace=True)

# %%
train[(train['bsmt_cond'].notnull())&(train['bsmt_exposure'].isnull())]
# Out:
#         id        pid  ms_subclass ms_zoning  lot_frontage  lot_area street  \
# 1456  1797  528458090           60        FV          81.0     10411   Pave
# 1547    67  528445060           20        RL          73.0      8987   Pave
# 1997  2780  907194130           60        RL          65.0     14006   Pave
#
#      alley lot_shape land_contour utilities lot_config land_slope  \
# 1456   NaN       Reg          Lvl    AllPub     Corner        Gtl
# 1547   NaN       Reg          Lvl    AllPub     Inside        Gtl
# 1997   NaN       IR1          Lvl    AllPub     Inside        Gtl
#
#      neighborhood condition_1 condition_2 bldg_type house_style  overall_qual  \
# 1456      Somerst        Norm        Norm      1Fam      2Story             5
# 1547      Somerst        Norm        Norm      1Fam      1Story             8
# 1997      CollgCr        Norm        Norm      1Fam      2Story             7
#
#       overall_cond  year_built  year_remod/add roof_style roof_matl  \
# ...

# %%
train.drop([1456,1547,1997],inplace=True)

# %%
train.loc[1147][33:39]
# Out:
# bsmt_exposure       No
# bsmtfin_type_1     GLQ
# bsmtfin_sf_1      1124
# bsmtfin_type_2     NaN
# bsmtfin_sf_2       479
# bsmt_unf_sf       1603
# Name: 1147, dtype: object

# %%
train.drop(1147,inplace=True)

# %%
test.columns
# Out:
# Index(['id', 'pid', 'ms_subclass', 'ms_zoning', 'lot_frontage', 'lot_area',
#        'street', 'alley', 'lot_shape', 'land_contour', 'utilities',
#        'lot_config', 'land_slope', 'neighborhood', 'condition_1',
#        'condition_2', 'bldg_type', 'house_style', 'overall_qual',
#        'overall_cond', 'year_built', 'year_remod/add', 'roof_style',
#        'roof_matl', 'exterior_1st', 'exterior_2nd', 'mas_vnr_type',
#        'mas_vnr_area', 'exter_qual', 'exter_cond', 'foundation', 'bsmt_qual',
#        'bsmt_cond', 'bsmt_exposure', 'bsmtfin_type_1', 'bsmtfin_sf_1',
#        'bsmtfin_type_2', 'bsmtfin_sf_2', 'bsmt_unf_sf', 'total_bsmt_sf',
#        'heating', 'heating_qc', 'central_air', 'electrical', '1st_flr_sf',
#        '2nd_flr_sf', 'low_qual_fin_sf', 'gr_liv_area', 'bsmt_full_bath',
#        'bsmt_half_bath', 'full_bath', 'half_bath', 'bedroom_abvgr',
#        'kitchen_abvgr', 'kitchen_qual', 'totrms_abvgrd', 'functional',
# ...

# %%
train[train.columns[31:40]].isnull().sum()
# Out:
# bsmt_qual         55
# bsmt_cond         55
# bsmt_exposure     55
# bsmtfin_type_1    55
# bsmtfin_sf_1       1
# bsmtfin_type_2    55
# bsmtfin_sf_2       1
# bsmt_unf_sf        1
# total_bsmt_sf      1
# dtype: int64

# %%
bsmt_qualitative = ['bsmt_qual','bsmt_cond','bsmt_exposure','bsmtfin_type_1','bsmtfin_type_2']

# %%
# Loop through and fill 'NA' values for all variables in 'bsmt_qualitative' list

for col in bsmt_qualitative:
    train[col].fillna('NA',inplace=True)
    test[col].fillna('NA',inplace=True)

# %%
bsmt_quantitative = ['bsmtfin_sf_1','bsmtfin_sf_2','bsmt_unf_sf','total_bsmt_sf']

# %%
# Loop through and fill 'NA' values for all variables in 'bsmt_quantitative' list

for col in bsmt_quantitative:
    train[col].fillna(0,inplace=True)
    test[col].fillna(0,inplace=True)

# %%
train[train.columns[31:55]].isnull().sum()
# Out:
# bsmt_qual          0
# bsmt_cond          0
# bsmt_exposure      0
# bsmtfin_type_1     0
# bsmtfin_sf_1       0
# bsmtfin_type_2     0
# bsmtfin_sf_2       0
# bsmt_unf_sf        0
# total_bsmt_sf      0
# heating            0
# heating_qc         0
# central_air        0
# electrical         0
# 1st_flr_sf         0
# 2nd_flr_sf         0
# low_qual_fin_sf    0
# gr_liv_area        0
# bsmt_full_bath     2
# bsmt_half_bath     2
# full_bath          0
# half_bath          0
# bedroom_abvgr      0
# kitchen_abvgr      0
# kitchen_qual       0
# dtype: int64

# %%
train[['bsmt_qual','bsmt_cond','bsmt_exposure',
          'bsmtfin_type_1','bsmtfin_type_2']].head()
# Out:
#   bsmt_qual bsmt_cond bsmt_exposure bsmtfin_type_1 bsmtfin_type_2
# 0        TA        TA            No            GLQ            Unf
# 1        Gd        TA            No            GLQ            Unf
# 2        TA        TA            No            GLQ            Unf
# 3        Gd        TA            No            Unf            Unf
# 4        Fa        Gd            No            Unf            Unf

# %%
train[(train.bsmt_full_bath.isnull())|(train.bsmt_half_bath.isnull())]
# Out:
#         id        pid  ms_subclass ms_zoning  lot_frontage  lot_area street  \
# 616   1498  908154080           20        RL         123.0     47007   Pave
# 1327  1342  903230120           20        RM          99.0      5940   Pave
#
#      alley lot_shape land_contour utilities lot_config land_slope  \
# 616    NaN       IR1          Lvl    AllPub     Inside        Gtl
# 1327   NaN       IR1          Lvl    AllPub        FR3        Gtl
#
#      neighborhood condition_1 condition_2 bldg_type house_style  overall_qual  \
# 616       Edwards        Norm        Norm      1Fam      1Story             5
# 1327      BrkSide       Feedr        Norm      1Fam      1Story             4
#
#       overall_cond  year_built  year_remod/add roof_style roof_matl  \
# 616              7        1959            1996      Gable   CompShg
# 1327             7        1946            1950      Gable   CompShg
#
#      exterior_1st exterior_2nd mas_vnr_type  mas_vnr_area exter_qual  \
# ...

# %%
# Fill 'NA' values for training and holdout dataframes for 'full_bath', 'half_bath'

train.bsmt_full_bath.fillna(0,inplace=True)
train.bsmt_half_bath.fillna(0,inplace=True)

# %%
test.bsmt_full_bath.fillna(0,inplace=True)
test.bsmt_half_bath.fillna(0,inplace=True)

# %%
train[(train['bsmt_full_bath']==0)|(train['bsmt_half_bath']==0)][['bsmt_qual','bsmt_full_bath','bsmt_half_bath']].head()
# Out:
#   bsmt_qual  bsmt_full_bath  bsmt_half_bath
# 0        TA             0.0             0.0
# 1        Gd             1.0             0.0
# 2        TA             1.0             0.0
# 3        Gd             0.0             0.0
# 4        Fa             0.0             0.0

# %%
train[train.columns[55:]].isnull().sum()
# Out:
# totrms_abvgrd        0
# functional           0
# fireplaces           0
# fireplace_qu       993
# garage_type        113
# garage_yr_blt      114
# garage_finish      114
# garage_cars          1
# garage_area          1
# garage_qual        114
# garage_cond        114
# paved_drive          0
# wood_deck_sf         0
# open_porch_sf        0
# enclosed_porch       0
# 3ssn_porch           0
# screen_porch         0
# pool_area            0
# pool_qc           2026
# fence             1639
# misc_feature      1970
# misc_val             0
# mo_sold              0
# yr_sold              0
# sale_type            0
# saleprice            0
# dtype: int64

# %%
train[train['garage_yr_blt']>2010][['year_built','garage_yr_blt']]
# Out:
#       year_built  garage_yr_blt
# 1699        2006         2207.0

# %%
train.loc[1699,'garage_yr_blt'] = 2007

# %%
garage_na_cols = ['alley','fireplace_qu','garage_type',
                  'garage_finish','garage_qual','garage_cond',
                  'pool_qc','fence','misc_feature']

for col in garage_na_cols:
    train[col].fillna('NA',inplace=True)
    test[col].fillna('NA',inplace=True)

# %%
test.electrical.fillna('NA',inplace=True)

# %%
#get dummies for pave/gravel, central air,

# %%
# Converted to age to standardize against different years sold

train['age_at_sale'] = train['yr_sold'] - train['year_built']

# %%
test['age_at_sale'] = test['yr_sold'] - test['year_built']

# %%
# Standardizing age of remodel

train['age_of_remod'] = train['yr_sold'] - train['year_remod/add']

# %%
test['age_of_remod'] = test['yr_sold'] - test['year_remod/add']

# %%
train.describe().T
# Out:
#                   count          mean           std          min          25%  \
# id               2035.0  1.475402e+03  8.435807e+02          1.0        754.5
# pid              2035.0  7.144748e+08  1.887009e+08  526301100.0  528477035.0
# ms_subclass      2035.0  5.690663e+01  4.274736e+01         20.0         20.0
# lot_frontage     2035.0  5.825061e+01  3.295544e+01          0.0         44.0
# lot_area         2035.0  1.005988e+04  6.752934e+03       1300.0       7500.0
# overall_qual     2035.0  6.107125e+00  1.425406e+00          1.0          5.0
# overall_cond     2035.0  5.564619e+00  1.106931e+00          1.0          5.0
# year_built       2035.0  1.971524e+03  3.020244e+01       1872.0       1953.0
# year_remod/add   2035.0  1.984090e+03  2.106171e+01       1950.0       1964.0
# mas_vnr_area     2035.0  9.827961e+01  1.744407e+02          0.0          0.0
# bsmtfin_sf_1     2035.0  4.420786e+02  4.613641e+02          0.0          0.0
# ...

# %%
#finding outliers in saleprice
train.sort_values('saleprice',ascending=False)[:20]
# Out:
#         id        pid  ms_subclass ms_zoning  lot_frontage  lot_area street  \
# 1671    45  528150070           20        RL         100.0     12919   Pave
# 1964  1638  527216080           20        RL          52.0     51974   Pave
# 1692  2451  528360050           60        RL         114.0     17242   Pave
# 1796   434  528110090           60        RL         107.0     13891   Pave
# 151   2333  527212030           60        RL          85.0     16056   Pave
# 1164   424  528106020           20        RL         105.0     15431   Pave
# 623    457  528176030           20        RL         100.0     14836   Pave
# 138   2331  527210040           60        RL          60.0     18062   Pave
# 823     16  527216070           60        RL          47.0     53504   Pave
# 1592  2335  527214060           60        RL          82.0     16052   Pave
# 81     367  527214050           20        RL          63.0     17423   Pave
# ...

# %%
train[train['total_bsmt_sf']>4000]
# Out:
#         id        pid  ms_subclass ms_zoning  lot_frontage  lot_area street  \
# 960   1499  908154235           60        RL         313.0     63887   Pave
# 1885  2181  908154195           20        RL         128.0     39290   Pave
#
#      alley lot_shape land_contour utilities lot_config land_slope  \
# 960     NA       IR3          Bnk    AllPub     Corner        Gtl
# 1885    NA       IR1          Bnk    AllPub     Inside        Gtl
#
#      neighborhood condition_1 condition_2 bldg_type house_style  overall_qual  \
# 960       Edwards       Feedr        Norm      1Fam      2Story            10
# 1885      Edwards        Norm        Norm      1Fam      1Story            10
#
#       overall_cond  year_built  year_remod/add roof_style roof_matl  \
# 960              5        2008            2008        Hip   ClyTile
# 1885             5        2008            2009        Hip   CompShg
#
#      exterior_1st exterior_2nd mas_vnr_type  mas_vnr_area exter_qual  \
# ...

# %%
train.drop(train[train['total_bsmt_sf']>3000].index,inplace=True)

# %%
train[train['lot_area']>60000]
# Out:
#         id        pid  ms_subclass ms_zoning  lot_frontage  lot_area street  \
# 471   2116  906426060           50        RL           0.0    159000   Pave
# 694   2072  905301050           20        RL           0.0    115149   Pave
# 1854  2767  906475200           20        RL          62.0     70761   Pave
#
#      alley lot_shape land_contour utilities lot_config land_slope  \
# 471     NA       IR2          Low    AllPub    CulDSac        Sev
# 694     NA       IR2          Low    AllPub    CulDSac        Sev
# 1854    NA       IR1          Low    AllPub     Inside        Mod
#
#      neighborhood condition_1 condition_2 bldg_type house_style  overall_qual  \
# 471       ClearCr        Norm        Norm      1Fam      1.5Fin             6
# 694       ClearCr        Norm        Norm      1Fam      1Story             7
# 1854      ClearCr        Norm        Norm      1Fam      1Story             7
#
#       overall_cond  year_built  year_remod/add roof_style roof_matl  \
# ...

# %%
train.drop(train[train['lot_area']>60000].index,inplace=True)

# %%
train[train['totrms_abvgrd']>13]
# Out:
#        id        pid  ms_subclass ms_zoning  lot_frontage  lot_area street  \
# 858  2195  909176080          190        RH          60.0     10896   Pave
#
#     alley lot_shape land_contour utilities lot_config land_slope neighborhood  \
# 858  Pave       Reg          Bnk    AllPub     Inside        Gtl        SWISU
#
#     condition_1 condition_2 bldg_type house_style  overall_qual  overall_cond  \
# 858       Feedr        Norm    2fmCon      2.5Fin             6             7
#
#      year_built  year_remod/add roof_style roof_matl exterior_1st  \
# 858        1914            1995        Hip   CompShg      VinylSd
#
#     exterior_2nd mas_vnr_type  mas_vnr_area exter_qual exter_cond foundation  \
# 858      VinylSd         None           0.0         Fa         TA     CBlock
#
#     bsmt_qual bsmt_cond bsmt_exposure bsmtfin_type_1  bsmtfin_sf_1  \
# 858        TA        Fa            No            LwQ         256.0
#
# ...

# %%
train.drop(858,inplace=True)

# %%
train.describe().T
# Out:
#                   count          mean           std          min          25%  \
# id               2027.0  1.473812e+03  8.438858e+02          1.0        753.5
# pid              2027.0  7.140878e+08  1.886906e+08  526301100.0  528477035.0
# ms_subclass      2027.0  5.693389e+01  4.268979e+01         20.0         20.0
# lot_frontage     2027.0  5.815096e+01  3.240053e+01          0.0         44.0
# lot_area         2027.0  9.859275e+03  5.064900e+03       1300.0       7500.0
# overall_qual     2027.0  6.099655e+00  1.419417e+00          1.0          5.0
# overall_cond     2027.0  5.564874e+00  1.107771e+00          1.0          5.0
# year_built       2027.0  1.971493e+03  3.019738e+01       1872.0       1953.0
# year_remod/add   2027.0  1.984030e+03  2.106986e+01       1950.0       1964.0
# mas_vnr_area     2027.0  9.716626e+01  1.719385e+02          0.0          0.0
# bsmtfin_sf_1     2027.0  4.361870e+02  4.387251e+02          0.0          0.0
# ...

# %%
test.describe().T
# Out:
#                  count          mean           std          min          25%  \
# id               879.0  1.445588e+03  8.507171e+02          2.0        692.5
# pid              879.0  7.165050e+08  1.889135e+08  526302110.0  528486085.0
# ms_subclass      879.0  5.827076e+01  4.221139e+01         20.0         20.0
# lot_frontage     879.0  5.695563e+01  3.433868e+01          0.0         40.0
# lot_area         879.0  1.034092e+04  1.004734e+04       1477.0       7298.5
# overall_qual     879.0  6.054608e+00  1.374756e+00          2.0          5.0
# overall_cond     879.0  5.565415e+00  1.128422e+00          1.0          5.0
# year_built       879.0  1.970534e+03  3.040353e+01       1880.0       1954.0
# year_remod/add   879.0  1.984445e+03  2.045455e+01       1950.0       1967.0
# mas_vnr_area     879.0  1.068612e+02  1.882841e+02          0.0          0.0
# bsmtfin_sf_1     879.0  4.433970e+02  4.424802e+02          0.0          0.0
# ...

# %%
# Save values to intermediate file

train.to_csv('./datasets/train_cleaned.csv',index_label=False)
test.to_csv('./datasets/test_cleaned.csv',index_label=False)

# %%
#histogram
sns.distplot(train['saleprice']);

# %%
sns.barplot('ms_subclass','saleprice', data= train)

# %%
sns.barplot('exter_qual','saleprice', data= train)

# %%
sns.barplot('exter_cond','saleprice', data= train)

# %%
sns.barplot('sale_type','saleprice', data= train)

# %%
sns.barplot('house_style','saleprice', data= train)

# %%
train.ms_zoning.value_counts()
# Out:
# RL         1580
# RM          315
# FV           97
# C (all)      19
# RH           13
# A (agr)       2
# I (all)       1
# Name: ms_zoning, dtype: int64

# %%
test.ms_zoning.value_counts()
# Out:
# RL         675
# RM         146
# FV          38
# RH          13
# C (all)      6
# I (all)      1
# Name: ms_zoning, dtype: int64

# %%
zone_train = pd.get_dummies(train, columns=['ms_zoning'])

# %%
zone_test = pd.get_dummies(test, columns=['ms_zoning'])

# %%
zone_train.columns.tolist()[:5]
# Out:
# ['id', 'pid', 'ms_subclass', 'lot_frontage', 'lot_area']

# %%
# Dummy variables for 'ms_zoning'

col_list = ['ms_zoning_C (all)','ms_zoning_FV','ms_zoning_I (all)',
            'ms_zoning_RH','ms_zoning_RL','ms_zoning_RM']

for col in col_list:
    train[col] = zone_train[col] # Apply to DataFrames
    test[col] = zone_test[col]

# %%
train.head()
# Out:
#     id        pid  ms_subclass ms_zoning  lot_frontage  lot_area street alley  \
# 0  109  533352170           60        RL           0.0     13517   Pave    NA
# 1  544  531379050           60        RL          43.0     11492   Pave    NA
# 2  153  535304180           20        RL          68.0      7922   Pave    NA
# 3  318  916386060           60        RL          73.0      9802   Pave    NA
# 4  255  906425045           50        RL          82.0     14235   Pave    NA
#
#   lot_shape land_contour utilities lot_config land_slope neighborhood  \
# 0       IR1          Lvl    AllPub    CulDSac        Gtl       Sawyer
# 1       IR1          Lvl    AllPub    CulDSac        Gtl      SawyerW
# 2       Reg          Lvl    AllPub     Inside        Gtl        NAmes
# 3       Reg          Lvl    AllPub     Inside        Gtl       Timber
# 4       IR1          Lvl    AllPub     Inside        Gtl      SawyerW
#
# ...

# %%
# Creating separate column to be dummied so that original column can be mapped ordinally

train['bldg_type_d'] = train['bldg_type']
train['house_style_d'] = train['house_style']

# %%
test['bldg_type_d'] = test['bldg_type']
test['house_style_d'] = test['house_style']

# %%
train = pd.get_dummies(train, columns=['bldg_type_d','house_style_d'])

# %%
test = pd.get_dummies(test, columns=['bldg_type_d','house_style_d'])

# %%
# New columns for dummying

train['foundation_d'] = train['foundation']
train = pd.get_dummies(train,columns=['foundation_d'])

# %%
test['foundation_d'] = test['foundation']
test = pd.get_dummies(test, columns=['foundation_d'])

# %%
train['fireplace_qu_d'] = train['fireplace_qu']
test['fireplace_qu_d'] = test['fireplace_qu']

# %%
train = pd.get_dummies(train, columns=['fireplace_qu_d'])
test = pd.get_dummies(test, columns=['fireplace_qu_d'])

# %%
# New columns for dummying

train['heating_qc_d'] = train['heating_qc']
test['heating_qc_d'] = test['heating_qc']

train = pd.get_dummies(train, columns=['heating_qc_d'])

# %%
train.drop('heating_qc_d_Po',axis=1,inplace=True)

# %%
test = pd.get_dummies(test, columns=['heating_qc_d'])

# %%
train['electrical_d'] = train['electrical']

# %%
test['electrical_d'] = test['electrical']

# %%
train = pd.get_dummies(train, columns=['electrical_d'])

# %%
test = pd.get_dummies(test, columns=['electrical_d'])

# %%
test = test.rename({'electrical_d_NA':'electrical_d_Mix'}) # Rename empty value to missing empty value
test['electrical_d_Mix'] = 0 # Manual assignment of blank value

# %%
# Duplicate dummy variables

train['garage_type_d'] = train['garage_type']
train['misc_feature_d'] = train['misc_feature']
train = pd.get_dummies(train, columns=['garage_type_d','misc_feature_d'])

# %%
test['garage_type_d'] = test['garage_type']
test['misc_feature_d'] = test['misc_feature']

test = pd.get_dummies(test, columns=['garage_type_d','misc_feature_d'])

# %%
test['misc_feature_d_TenC'] = 0

# %%
train.ms_subclass.value_counts()
# Out:
# 20     760
# 60     386
# 50     197
# 120    131
# 30     101
# 70      90
# 80      86
# 160     85
# 90      75
# 190     45
# 85      28
# 75      16
# 180     11
# 45      11
# 40       4
# 150      1
# Name: ms_subclass, dtype: int64

# %%
# get dummies - TBD

subclass_dict = {
    '20': '1-STORY 1946 & NEWER ALL STYLES',
    '30': '1-STORY 1945 & OLDER',
    '40': '1-STORY W/ FINISHED ATTIC ALL AGES',
    '45': '1-HALF STORY - UNFINISHED ALL AGES',
    '50': '1-HALF STORY FINISHED ALL AGES',
    '60': '2-STORY 1946 & NEWER',
    '70': '2-STORY 1945 & OLDER',
    '75': '2-HALF STORY ALL AGES',
    '80': 'SPLIT OR MULTI-LEVEL',
    '85': 'SPLIT FOYER',
    '90': 'DUPLEX - ALL STYLES AND AGES',
    '120': '1-STORY PUD (Planned Unit Development) - 1946 & NEWER',
    '150': '1-HALF STORY PUD - ALL AGES',
    '160': '2-STORY PUD - 1946 & NEWER',
    '180': 'PUD - MULTILEVEL - INCL SPLIT LEV/FOYER',
    '190': '2 FAMILY CONVERSION - ALL STYLES AND AGES'
}

# %%
# Duplicate dummy columns

train['sale_type_d'] =train['sale_type']

train = pd.get_dummies(train, columns=['sale_type_d'])

# %%
test['sale_type_d'] = test['sale_type']

test = pd.get_dummies(test, columns=['sale_type_d'])

# %%
test.drop('sale_type_d_VWD',axis=1,inplace=True)

# %%
# Dummies for exterior and condition, originals later to be mapped ordinally

train['exterior_1st_d'] = train['exterior_1st']
train['exterior_2nd_d'] = train['exterior_2nd']
train['condition_1_d'] = train['condition_1']
train['condition_2_d'] = train['condition_2']

train = pd.get_dummies(train, columns=['exterior_1st_d','exterior_2nd_d','condition_1_d','condition_2_d'])

# %%
test['exterior_1st_d'] = test['exterior_1st']
test['exterior_2nd_d'] = test['exterior_2nd']
test['condition_1_d'] = test['condition_1']
test['condition_2_d'] = test['condition_2']

test = pd.get_dummies(test, columns=['exterior_1st_d','exterior_2nd_d','condition_1_d','condition_2_d'])

# %%
train['exterior_1st_d_PreCast'] = 0  # Fill in missing columns in test DF
train['exterior_2nd_d_Other'] = 0
train['exterior_2nd_d_PreCast'] = 0

# %%
test['exterior_1st_d_CBlock'] = 0
test['exterior_1st_d_ImStucc'] = 0  # Fill in missing columns in holdout DF
test['exterior_1st_d_Stone'] = 0    # Dataframes match columns
test['condition_2_d_RRAe'] = 0
test['condition_2_d_RRAn'] = 0
test['condition_2_d_RRNn'] = 0
test['condition_2_d_Artery'] = 0

# %%
train['mas_vnr_type_d'] = train['mas_vnr_type']
train = pd.get_dummies(train, columns=['mas_vnr_type_d'])

# %%
test['mas_vnr_type_d'] = test['mas_vnr_type']
test = pd.get_dummies(test, columns=['mas_vnr_type_d'])

# %%
train['roof_style_d'] = train['roof_style']
train['roof_matl_d'] = train['roof_matl']

train = pd.get_dummies(train, columns=['roof_style_d','roof_matl_d'])

# %%
test['roof_style_d'] = test['roof_style']
test['roof_matl_d'] = test['roof_matl']

test = pd.get_dummies(test, columns=['roof_style_d','roof_matl_d'])

# %%
test.drop('roof_matl_d_Metal',axis=1,inplace=True)

# %%
test['roof_matl_d_Membran'] = 0

# %%
train['neighborhood_d'] = train['neighborhood']
test['neighborhood_d'] = test['neighborhood']

train = pd.get_dummies(train, columns=['neighborhood_d'])
test = pd.get_dummies(test, columns=['neighborhood_d'])

# %%
# Dict of all columns associated with ordinal categories

link_d = { # link dictionary
    'qual':['fireplace_qu','exter_qual','exter_cond','heating_qc','kitchen_qual',
             'bsmt_qual','pool_qc','garage_qual','garage_cond'],
    'fence':['fence'],
    'paved_drive':['paved_drive'],
    'garage_finish':['garage_finish'],
    'bsmtfin':['bsmtfin_type_1','bsmtfin_type_2'],
    'bsmt_exposure':['bsmt_exposure'],
    'lot_shape':['lot_shape'],
    'land_contour':['land_contour'],
    'utilities':['utilities'],
    'land_slope':['land_slope'],
    'condition':['condition_1','condition_2'],
    'bldg_type':['bldg_type'],
    'house_style':['house_style'],
    'roof_style':['roof_style'],
    'roof_matl':['roof_matl'],
    'exterior':['exterior_1st','exterior_2nd','mas_vnr_type'],
    'foundation':['foundation'],
    'garage_type':['garage_type'],
    'sale_type':['sale_type'],
}

# %%
# Ratings for elements of each category key

dod = { # dictionary of dictionaries
    'qual':{'Ex':5,'Gd':4,'TA':3,'Fa':2,'Po':1,'NA':0},
    'fence':{'GdPrv':4,'MnPrv':3,'GdWo':2,'MnWw':1,'NA':0},
    'paved_drive':{'Y':2,'P':1,'N':0},
    'garage_finish':{'Fin':3,'RFn':2,'Unf':1,'NA':0},
    'bsmtfin':{'GLQ':6,'ALQ':5,'BLQ':4,'Rec':3,'LwQ':2,'Unf':1,'NA':0},
    'bsmt_exposure':{'Gd':4,'Av':3,'Mn':2,'No':1,'NA':0},
    'lot_shape':{'Reg':0,'IR1':-1,'IR2':-2,'IR3':-3},
    'land_contour':{'Lvl':0,'Bnk':-1,'HLS':-2,'Low':-3},
    'utilities':{'AllPub':0,'NoSewr':-1,'NoSeWa':-2,'ELO':-3},
    'land_slope':{'Gtl':0,'Mod':-1,'Sev':-2},
    'condition':{'PosA':3,'PosN':2,'Norm':1,'Feedr':-2,'Artery':-2,'RRNn':0,
                 'RRAn':-1,'RRNe':0,'RRAe':-1},
    'bldg_type':{'1Fam':3,'TwnhsE':2,'Duplex':1,'Twnhs':0,'2fmCon':0},
    'house_style':{'1Story':2,'1.5Unf':3,'1.5Fin':4,'2Story':5,'2.5Unf':6,'2.5Fin':7,
                  'SLvl':1,'SFoyer':0},
    'roof_style':{'Gable':2,'Hip':2,'Flat':0,'Gambrel':2,'Mansard':2,'Shed':1},
    'roof_matl':{'CompShg':1,'Tar&Grv':-1,'WdShngl':2,'WdShake':0,'Membran':2,
                 'Metal':2,'Roll':-1},
    'exterior':{'VinylSd':4,'MetalSd':3,'HdBoard':-1,'Wd Sdng':2,'Plywood':-1,
                'CemntBd':0,'CmentBd':0,'BrkFace':1,'WdShing':2,'AsbShng':-2,
                'Stucco':2,'BrkComm':1,'CBlock':-1,'Stone':5,'AsphShn':3,'ImStucc':1,
                'PreCast':-1,'Other':0,'None':0},
    'foundation':{'PConc':3,'CBlock':-2,'BrkTil':0,'Slab':1,'Stone':2,'Wood':-1},
    'garage_type':{'Attchd':6,'BuiltIn':5,'2Types':4,'Basment':3,'CarPort':2,
                   'NA':0,'Detchd':0},
    'sale_type':{'New':4,'Con':3,'ConLI':2,'CWD':1,'Oth':0,'ConLw':-1,'ConLD':-2,
                 'COD':-3,'WD':-4,'WD ':-4,'VWD':-4}
}

# %%
# DF and Pred Columns to apply ordinal mapping to

cols_for_dict = ['fireplace_qu','exter_qual','exter_cond','heating_qc',
                 'kitchen_qual','bsmt_qual','pool_qc','garage_qual','garage_cond',
                 'fence','paved_drive','garage_finish','bsmt_exposure','lot_shape',
                 'land_contour','utilities','land_slope','condition_1','condition_2',
                 'bldg_type','house_style','roof_style','roof_matl','exterior_1st',
                 'exterior_2nd','mas_vnr_type','foundation','garage_type','sale_type']

# %%
train.bldg_type.value_counts()
# Out:
# 1Fam      1681
# TwnhsE     158
# Duplex      75
# Twnhs       68
# 2fmCon      45
# Name: bldg_type, dtype: int64

# %%
# Refresh data types to pd.Datetime

#to_dt_cols = ['year_built','year_remod/add','yr_sold']

#for col in to_dt_cols:
#    dt_fmt = pd.to_datetime(train[col],format='%Y')
 #   dt_fmt_pred = pd.to_datetime(test[col],format='%Y')
  #  train[col] = dt_fmt.dt.year
   # test[col] = dt_fmt_pred.dt.year

# %%
#train.loc[train[train['garage_yr_blt']==''].index,'garage_yr_blt'] = pd.NaT

# %%
#test.loc[test[test['garage_yr_blt']==''].index,'garage_yr_blt'] = pd.NaT

# %%
#dt_fmt = pd.to_datetime(train.garage_yr_blt,format='%Y.%f')
#dt_fmt_pred = pd.to_datetime(test.garage_yr_blt,format='%Y.%f')

# %%
#train.loc[:,'garage_yr_blt'] = dt_fmt.dt.year
#test.loc[:,'garage_yr_blt'] = dt_fmt_pred.dt.year

# %%
#train.loc[train[train['garage_yr_blt'].isnull()].index,'garage_yr_blt'] = pd.NaT

# %%
#test.loc[test[test['garage_yr_blt'].isnull()].index,'garage_yr_blt'] = pd.NaT

# %%
# Heatmap of every correlation with 'saleprice'

plt.figure(figsize=(7,24))
sns.heatmap(train.corr()[['saleprice']].sort_values('saleprice',ascending=False),
            annot=True,cmap='Blues');

# %%
train.corr()[['saleprice']].sort_values('saleprice',ascending=False)[:5]
# Out:
#                saleprice
# saleprice       1.000000
# overall_qual    0.804095
# gr_liv_area     0.719703
# total_bsmt_sf   0.660388
# garage_area     0.658562

# %%
corr_list = ['saleprice','overall_qual','gr_liv_area',
             'garage_area','gr_liv_area','total_bsmt_sf']

# %%
plt.figure(figsize=(12,6))
sns.heatmap(corr_df,annot=True,cmap='BrBG'); # Heatmaps for group of 12
        
corr_df = pd.DataFrame()
corr_df_names = pd.DataFrame()

# %%
plt.figure(figsize=(12,8))
sns.heatmap(train[['saleprice','overall_qual','overall_cond','gr_liv_area',
             'garage_area', 'garage_cars','1st_flr_sf','age_at_sale','lot_area']].corr(),annot=True,cmap='Blues');

# %%
sns.pairplot(train, 
             x_vars=['overall_qual','overall_cond','age_at_sale','garage_cars','lot_area'],
            y_vars=['saleprice'],)

# %%
# Fill 'NA' values for garage year built

train.garage_yr_blt.fillna(0,inplace=True)
test.garage_yr_blt.fillna(0,inplace=True)

# %%
# TempDrop 'NA' values for garage year built

train.garage_cars.dropna(inplace=True)
test.garage_cars.dropna(inplace=True)

train.garage_area.dropna(inplace=True)
test.garage_area.dropna(inplace=True)

# %%
for col in train:
    if type(train[col])== 'int64' or 'float64':
        train[col] = train[col].fillna(value=0)
    else:
        train[col] = train[col].fillna(value='None')

# %%
train.isnull().sum().sum()
# Out:
# 0

# %%
# Select numeric columns only from training data as features, then remove saleprice

# A:

features = [col for col in train._get_numeric_data() if col != 'SalePrice']
X = train[features]
y = train['saleprice']

# %%
X = X.astype(float)
X_holdout = X_holdout.astype(float)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=126)

# %%
X_train.shape
# Out:
# (1520, 4)

# %%
#initialize scaler
ss = StandardScaler()
ss.fit(X_train)
X_train_scaled = ss.transform(X_train)
X_test_scaled = ss.transform(X_test)

#should only scale the train set. Assuming test is fully unseen data.

# %%
# Linear Regression model instantiation

lr = LinearRegression()

# %%
ridge = RidgeCV(alphas = np.linspace(0.1,10,100))

# %%
#LR estimate test r2 using cross val
lr_cv_score = cross_val_score(lr, X_train_scaled, y_train, cv = 5).mean()
lr_cv_score
# Out:
# 0.9981983344891086

# %%
#LR estimate test RMSE using cross val
lr_cv_score_RMSE = -cross_val_score(lr, X_train_scaled, y_train, cv = 5, scoring= 'neg_root_mean_squared_error').mean()
lr_cv_score_RMSE
# Out:
# 2405.920068199453

# %%
#Ridge estimate test R2 using cross val
ridge_cv_score = cross_val_score(ridge, X_train_scaled, y_train, cv = 5).mean()
ridge_cv_score
# Out:
# 0.9999998252750677

# %%
lr.fit(X_train_scaled, y_train)

print("Training R2(LR) " + str(lr.score(X_train_scaled, y_train)))
print("Test R2(LR) " + str(lr.score(X_test_scaled, y_test)))
print("Estimate of test R2(LR) " + str(lr_cv_score))
# Out:
# Training R2(LR) 1.0
# Test R2(LR) 0.9999969600663349
# Estimate of test R2(LR) 0.9981983344891086
